# %% [markdown]
# <a href="https://colab.research.google.com/github/GDIAMEL/WIKIPEDIA-SCRAPPED-DATA-/blob/main/SAMUEL_EMMANUEL_KIMARO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BEST PERFORMING USA COMPANIES BY REVENUE**

# %% [markdown]
# # **INTRODUCTION**

# %% [markdown]
# This project aims to explore and analyze the largest companies in the United States based on their annual revenue. The U.S. is home to some of the world’s most powerful corporations, spanning industries such as technology, healthcare, retail, and energy. These companies not only dominate their respective sectors but also play a significant role in shaping the global economy.
#
# By examining the top revenue-generating companies, this analysis will provide insights into their business models, market dominance, and financial performance. The data collected will help highlight key trends in the U.S. corporate landscape, such as shifts in consumer demand, technological innovation, and the impact of global economic conditions on various industries.
#
# The findings from this project will shed light on which companies are driving economic growth and how their strategies have contributed to their success, offering valuable information for investors, analysts, and business leaders.

# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **LOADING THE DATA**

# %%
df = pd.read_csv('/content/USA_COMPANIES_PERFORMANCE_BY_REVENUE (1).CSV')

# %% [markdown]
# ## **EXPLORING THE DATA**

# %%
# getting the data overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    object
#  4   Revenue growth          100 non-null    object
#  5   Employees               100 non-null    object
#  6   Headquarters            100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
# viewing the first five data sample
df.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3               Apple        Electronics industry
# 3     4  UnitedHealth Group                  Healthcare
# 4     5  Berkshire Hathaway                Conglomerate
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0                648,125           6.0%  2,100,000  Bentonville, Arkansas
# 1                574,785          11.9%  1,525,000    Seattle, Washington
# 2                383,482          -2.8%    161,000  Cupertino, California
# 3                371,622          14.6%    440,000  Minnetonka, Minnesota
# 4                364,482          20.7%    396,500        Omaha, Nebraska

# %%
# viewing the last five data sample
df.tail()
# Out:
#     Rank                  Name                 Industry  \
# 95    96                  TIAA               Financials
# 96    97                   CHS  Agriculture cooperative
# 97    98  Bristol-Myers Squibb  Pharmaceutical industry
# 98    99  Dow Chemical Company        Chemical industry
# 99   100              Best Buy                   Retail
#
#    Revenue (USD millions) Revenue growth Employees  \
# 95                 45,735          11.8%    16,023
# 96                 45,590          -4.6%    10,609
# 97                 45,006          -2.5%    34,100
# 98                 44,622         -21.6%    35,900
# 99                 43,452          -6.1%    85,000
#
#                       Headquarters
# 95         New York City, New York
# 96  Inver Grove Heights, Minnesota
# 97         New York City, New York
# 98               Midland, Michigan
# 99            Richfield, Minnesota

# %%
# viewing the statistical information of the data
df.describe()
# Out:
#              Rank
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
! pip install pandas-profiling

# %%
# accessing the overall data report using data profiling
from ydata_profiling import ProfileReport
ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.10.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-09-14 06:24:00.250847&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # **DATA CLEANING**

# %%
# checking for missing values
df.isnull().sum()
# Out:
# Rank                      0
# Name                      0
# Industry                  0
# Revenue (USD millions)    0
# Revenue growth            0
# Employees                 0
# Headquarters              0
# dtype: int64

# %% [markdown]
# When using .isnull, 0 or false means there are no missing values but if the boolean is true or there is a  number greater than 0 then there are missing values in the data.

# %%
# checking for data duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The above shows that there are no duplicates in the data.

# %% [markdown]
# ## **REGRESSION ANALYSIS**

# %%
# CONDUCTING MATCHINE LEARNING FOR THE DATA
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # **DATA VISUALIZATION**

# %%
# Convert 'Revenue (USD millions)' to numeric, ignoring errors
df['Revenue (USD millions)'] = pd.to_numeric(df['Revenue (USD millions)'], errors='coerce')

# Now find the top 10 companies by revenue
top10_companies = df.nlargest(10, 'Revenue (USD millions)')[["Name", "Revenue (USD millions)"]]

top10_companies
# Out:
#                    Name  Revenue (USD millions)
# 0               Walmart                     NaN
# 1                Amazon                     NaN
# 2                 Apple                     NaN
# 3    UnitedHealth Group                     NaN
# 4    Berkshire Hathaway                     NaN
# 5            CVS Health                     NaN
# 6            ExxonMobil                     NaN
# 7              Alphabet                     NaN
# 8  McKesson Corporation                     NaN
# 9               Cencora                     NaN

# %% [markdown]
# # T**O THE ONES WHO WILL VIEW THIS THE PROJECT IS NOT COMPLETE FOR NOW **
